# %%
import os
import requests
import json
import pandas as pd

# %%
TTBKEY = 'ttbqkrdlstn97011854001'

# %%
CategoryId = [
    351, 2630, 2643, 2632, 2672, 2669, 7439, 2633, 2673, 2648, 2655, 2645, 55977, 55981, 55978, 
    55979, 55055, 55057, 55056, 2599, 2607, 2602, 2601, 2606, 2608, 2600, 6348, 2663, 2665, 2662, 
    7395, 2661, 6163, 6165, 2666, 6355, 128622, 128624, 128623, 2719, 2737, 6794, 2744, 2724, 2732, 
    2735, 3239, 2721, 5056, 5058, 5059, 5061, 5063, 6576, 6577, 6578, 7396, 6589, 2756, 7411, 427, 
    6593, 2065, 2509, 2510, 2684, 1714, 2753, 6188, 35322, 6627, 2687, 6720, 437, 6356, 6358, 6360, 
    6361, 6362, 6365, 6989, 2502, 6734, 6357, 14605, 6350, 6385, 6386, 7397, 35323, 2704, 6351, 
    15778, 6353, 6352, 6437, 479, 6892, 2836, 6995, 6996, 6997, 12984, 485, 2999, 2847, 7013, 7012, 
    7014, 6891, 483, 486, 7006, 7007, 5581, 68185, 36134, 6636, 2835, 6436, 2839, 2838, 2349, 2413, 
    2757, 2350, 363, 6369, 387, 6381, 2767, 2765, 49733, 2770, 2773, 2766, 2613, 6346, 6889, 6890, 
    2615, 3023, 2621
]

# %%
def make_book(CategoryId, ttbkey=TTBKEY, QueryType="Bestseller"):
    url = "http://www.aladin.co.kr/ttb/api/ItemList.aspx"
    params = {
        "TTBKey": ttbkey,
        "QueryType": QueryType,
        "Version": "20131101",
        "SearchTarget": "Book",
        "CategoryId": CategoryId
    }
    
    try:
        response = requests.get(url, params=params, timeout=10)
        print(f"응답 데이터: {response.text}")
        print(f"HTTP 응답 상태 코드: {response.status_code}")  # 상태 코드 확인
        response.raise_for_status()  # HTTP 에러 발생 시 예외 처리
        data = response.json()  # JSON 데이터 파싱
    except (requests.RequestException, json.JSONDecodeError) as e:
        print(f"API 호출 오류: {e}")
        return pd.DataFrame()  # 빈 데이터프레임 반환
    
    if "item" in data:
        items = [
            {
                "title": item.get("title", ""),
                "link": item.get("link", ""),
                "author": item.get("author", ""),
                "pubDate": item.get("pubDate", ""),
                "description": item.get("description", ""),
                "isbn": item.get("isbn", ""),
                "isbn13": item.get("isbn13", ""),
                "itemId": item.get("itemId", ""),
                "priceSales": item.get("priceSales", ""),
                "priceStandard": item.get("priceStandard", ""),
                "categoryId": item.get("categoryId", ""),
                "categoryName": item.get("categoryName", ""),
                "publisher": item.get("publisher", ""),
                "customerReviewRank": item.get("customerReviewRank", ""),
            }
            for item in data["item"]
        ]
        return pd.DataFrame(items)
    else:
        print("API 호출 성공, 그러나 반환된 데이터가 없습니다.")
        return pd.DataFrame()  # 빈 데이터프레임 반환

# %%
make_book()
# Out:
# 응답 데이터: <?xml version="1.0" encoding="UTF-8"?>
# <object xmlns="http://www.aladin.co.kr/ttb/apiguide.aspx">
#     <title>알라딘 베스트셀러 리스트 - 컴퓨터/모바일</title>
#     <link>https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=Bestseller&amp;BranchType=1&amp;CID=351&amp;Year=2025&amp;Month=1&amp;Week=4&amp;partner=openAPI</link>
#     <logo>http://image.aladin.co.kr/img/header/2011/aladin_logo_new.gif</logo>
# 	<pubDate>Mon, 27 Jan 2025 02:48:35 GMT</pubDate>
# 	<totalResults>1000</totalResults>
#     <startIndex>1</startIndex>
#     <itemsPerPage>10</itemsPerPage>
#     <query>QueryType=BESTSELLER;CategoryId=351;Year=2025;Month=1;Week=4</query>
#     <version>20131101</version>
#     <searchCategoryId>351</searchCategoryId>
#     <searchCategoryName>컴퓨터/모바일</searchCategoryName>
#
# 			<item itemId="356471630">
# 			    <title>AI 시대 생존 전략 - 구글 AI 엔지니어가 공개한 AI 활용 비법</title>
# 				<link>http://www.aladin.co.kr/shop/wproduct.aspx?ItemId=356471630&amp;partner=openAPI&amp;start=api</link>
# 				<author>세가 쳉 (지은이), 홍민경 (옮긴이), 샤오위핀 (정리)</author>
# 				<pubDate>2025-02-10</pubDate>
# 				<description>AI 혁명 시대에 생존과 성공을 위한 전략을 직장, 학습, 비즈니스, 미래라는 4가지 영역에 걸쳐 구체적이고 실질적으로 제시한다. 예를 들어 AI 기술을 자신의 조력자로 삼아 업무 생산성을 높이기, 인문학적 소양과 논리적 사고를 통해 AI 시대에서도 경쟁력 유지하기, 그리고 기존 비즈니스 모델의 핵심 가치를 AI로 강화하는 접근법 등을 조목조목 알려 준다.</description>
# 				<isbn>K452036719</isbn>
# 				<isbn13>9791194156116</isbn13>
# 				<priceSales>16920</priceSales>
# 				<priceStandard>18800</priceStandard>
# 				<mallType>BOOK</mallType>
# 				<stockStatus>예약판매</stockStatus>
# 				<mileage>940</mileage>
# 				<cover>https://image.aladin.co.kr/product/35647/16/coversum/k452036719_1.jpg</cover>
# 				<categoryId>70216</categoryId>
# 				<categoryName>국내도서&gt;자기계발&gt;성공&gt;성공학</categoryName>
# 				<publisher>더페이지</publisher>
# 				<salesPoint>5790</salesPoint>
#                 <adult>false</adult>
#
# 				<fixedPrice>true</fixedPrice>
#
# 				<customerReviewRank>0</customerReviewRank>
#
#                 <bestRank>1</bestRank>
#
#
#
# 			    <subInfo>
#
#
#
#
#
# 			    </subInfo>
#
#
#
#
# 			</item>
#
# 			<item itemId="346891281">
# 			    <title>박태웅의 AI 강의 2025 - 인공지능의 출현부터 일상으로의 침투까지 우리와 미래를 함께할 새로운 지능의 모든 것</title>
# 				<link>http://www.aladin.co.kr/shop/wproduct.aspx?ItemId=346891281&amp;partner=openAPI&amp;start=api</link>
# 				<author>박태웅 (지은이)</author>
# 				<pubDate>2024-09-30</pubDate>
# 				<description>베스트셀러 《박태웅의 AI 강의》가 최신 AI 트렌드와 더 깊은 인사이트를 담아 돌아왔다. 인공지능 원리에 대한 쉬운 설명은 그대로 유지한 채 더욱 깊이 있는 기술 지식이 책 곳곳에 추가되었고, 우리가 반드시 알아야 할 AI 트렌드는 물론이요, AI로 인해 변화될 앞으로의 우리 모습까지 조망하고 있다.</description>
# 				<isbn>K522933817</isbn>
# 				<isbn13>9791157847679</isbn13>
# 				<priceSales>16920</priceSales>
# 				<priceStandard>18800</priceStandard>
# 				<mallType>BOOK</mallType>
# 				<stockStatus></stockStatus>
# 				<mileage>940</mileage>
# 				<cover>https://image.aladin.co.kr/product/34689/12/coversum/k522933817_1.jpg</cover>
# 				<categoryId>197415</categoryId>
# 				<categoryName>국내도서&gt;경제경영&gt;트렌드/미래전망&gt;인공지능/빅데이터</categoryName>
# 				<publisher>한빛비즈</publisher>
# 				<salesPoint>60691</salesPoint>
#                 <adult>false</adult>
#
# 				<fixedPrice>true</fixedPrice>
#
# 				<customerReviewRank>10</customerReviewRank>
#
#                 <bestRank>2</bestRank>
#
#
#
# 			    <subInfo>
#
#
#
#
#
# 			    </subInfo>
#
#
#
#
# 			</item>
#
# 			<item itemId="288198356">
# 			    <title>진짜 쓰는 실무 엑셀 - 유튜브 대표 엑셀 채널, 오빠두가 알려 주는 엑셀 함수, 보고서 작성, 데이터 분석 노하우!</title>
# 				<link>http://www.aladin.co.kr/shop/wproduct.aspx?ItemId=288198356&amp;partner=openAPI&amp;start=api</link>
# 				<author>오빠두(전진권) (지은이)</author>
# 				<pubDate>2022-02-15</pubDate>
# 				<description>대기업 직장 생활 10년의 실무 노하우와 엑셀 유튜브 채널을 운영하면서 들은 수많은 직장인의 고민을 해결할 수 있는 다양한 엑셀 비법을 담았다. '진짜 쓰는 실무 엑셀' 한 권이면 빠른 일 처리로 워라밸을 실현하고, 일잘러로 거듭날 수 있다!</description>
# 				<isbn>K152836497</isbn>
# 				<isbn13>9791191600704</isbn13>
# 				<priceSales>18900</priceSales>
# 				<priceStandard>21000</priceStandard>
# 				<mallType>BOOK</mallType>
# 				<stockStatus></stockStatus>
# 				<mileage>1050</mileage>
# 				<cover>https://image.aladin.co.kr/product/28819/83/coversum/s292938843_1.jpg</cover>
# 				<categoryId>2602</categoryId>
# 				<categoryName>국내도서&gt;컴퓨터/모바일&gt;오피스(엑셀/파워포인트)&gt;엑셀</categoryName>
# 				<publisher>제이펍</publisher>
# 				<salesPoint>80882</salesPoint>
#                 <adult>false</adult>
#
# 				<fixedPrice>true</fixedPrice>
#
# 				<customerReviewRank>10</customerReviewRank>
#
#                 <bestRank>3</bestRank><seriesInfo><seriesId>1020476</seriesId><seriesLink>http://www.aladin.co.kr/shop/common/wseriesitem.aspx?SRID=1020476&amp;partner=openAPI</seriesLink><seriesName>진짜 쓰는 시리즈 </seriesName></seriesInfo>
#
#
#
# 			    <subInfo>
#
#
#
#
#
# 			    </subInfo>
#
#
#
#
# 			</item>
#
# 			<item itemId="354739009">
# 			    <title>이게 되네? 챗GPT 미친 활용법 71제 - 전면 개정 2판, 7배 더 빠르게, 7배 나은 퀄리티로 진짜 현업에 사용해온 오대리의 ‘71가지 미친 업무 자동화’ with o1, 소라, 캔버스, 서치, 프로젝트, 고급 음성모드, GPTs</title>
# 				<link>http://www.aladin.co.kr/shop/wproduct.aspx?ItemId=354739009&amp;partner=openAPI&amp;start=api</link>
# 				<author>오힘찬 (지은이)</author>
# 				<pubDate>2025-01-10</pubDate>
# 				<description>챗GPT 분야 25주 연속 베스트셀러인 《이게 되네? 챗GPT 미친 활용법 51제》가 최신 챗GPT 업데이트를 반영하여 완전히 새로운 개정판으로 다시 찾아왔다. 인공지능 시대에 일잘러, 작가, 영상 편집자, 현인으로서 살아갈 여러분의 마법의 지팡이가 되어줄 것이다.</description>
# 				<isbn>K772035440</isbn>
# 				<isbn13>9791194383116</isbn13>
# 				<priceSales>21600</priceSales>
# 				<priceStandard>24000</priceStandard>
# 				<mallType>BOOK</mallType>
# 				<stockStatus></stockStatus>
# 				<mileage>1200</mileage>
# 				<cover>https://image.aladin.co.kr/product/35473/90/coversum/k772035440_1.jpg</cover>
# 				<categoryId>3023</categoryId>
# 				<categoryName>국내도서&gt;컴퓨터/모바일&gt;PC/게임/디지털 카메라&gt;초보자를 위한 컴퓨터 책</categoryName>
# 				<publisher>골든래빗(주)</publisher>
# 				<salesPoint>7630</salesPoint>
#                 <adult>false</adult>
#
# 				<fixedPrice>true</fixedPrice>
#
# 				<customerReviewRank>10</customerReviewRank>
#
#                 <bestRank>4</bestRank><seriesInfo><seriesId>1216953</seriesId><seriesLink>http://www.aladin.co.kr/shop/common/wseriesitem.aspx?SRID=1216953&amp;partner=openAPI</seriesLink><seriesName>이게 되네? </seriesName></seriesInfo>
#
#
#
# 			    <subInfo>
#
#
#
#
#
# 			    </subInfo>
#
#
#
#
# 			</item>
#
# 			<item itemId="352551557">
# 			    <title>AI 2025 - 트렌드 &amp; 활용백과</title>
# 				<link>http://www.aladin.co.kr/shop/wproduct.aspx?ItemId=352551557&amp;partner=openAPI&amp;start=api</link>
# 				<author>김덕진 (지은이)</author>
# 				<pubDate>2024-11-29</pubDate>
# 				<description>2025년, 우리는 AI와 더 깊이 연결되는 ‘AI 2학년’이 되었다. 절대 놓쳐서는 안 될 2025년 AI 트렌드와 활용법. 10여 년 동안 IT 트렌드의 최전선에서 대중들과 함께 호흡해온 김덕진 IT커뮤니케이션연구소장이 MS, 구글, 애플, 오픈AI, 네이버 등 빅테크 기업들의 최신 전략을 분석하고, 2025년 AI 트렌드를 정리한다.</description>
# 				<isbn>K242934144</isbn>
# 				<isbn13>9791193674185</isbn13>
# 				<priceSales>22500</priceSales>
# 				<priceStandard>25000</priceStandard>
# 				<mallType>BOOK</mallType>
# 				<stockStatus></stockStatus>
# 				<mileage>1250</mileage>
# 				<cover>https://image.aladin.co.kr/product/35255/15/coversum/k242934144_1.jpg</cover>
# 				<categoryId>2173</categoryId>
# 				<categoryName>국내도서&gt;경제경영&gt;기업 경영&gt;경영전략/혁신</categoryName>
# 				<publisher>스마트북스</publisher>
# 				<salesPoint>13650</salesPoint>
#                 <adult>false</adult>
#
# 				<fixedPrice>true</fixedPrice>
#
# 				<customerReviewRank>10</customerReviewRank>
#
#                 <bestRank>5</bestRank>
#
#
#
# 			    <subInfo>
#
#
#
#
#
# 			    </subInfo>
#
#
#
#
# 			</item>
#
# 			<item itemId="352911519">
# 			    <title>AI 리터러시 : 인공지능 필수 지식부터 완벽 활용까지 - 여전히 챗GPT만 붙들고 있는 당신에게</title>
# 				<link>http://www.aladin.co.kr/shop/wproduct.aspx?ItemId=352911519&amp;partner=openAPI&amp;start=api</link>
# 				<author>김용성 (지은이)</author>
# 				<pubDate>2024-12-02</pubDate>
# 				<description>이 정도쯤은 알아야 할 수준으로 선별한 'AI와 데이터 지식'을 일러스트와 함께 친절하게 설명하며 출발한다. 인공지능의 탄생과 작동 원리부터 시작해 AI가 요즘과 근미래에 우리 사회에 끼칠 영향을 두루 조망하며 AI 시대에 대한 균형 잡힌 시각을 선보인다.</description>
# 				<isbn>8965404029</isbn>
# 				<isbn13>9788965404026</isbn13>
# 				<priceSales>22500</priceSales>
# 				<priceStandard>25000</priceStandard>
# 				<mallType>BOOK</mallType>
# 				<stockStatus></stockStatus>
# 				<mileage>1250</mileage>
# 				<cover>https://image.aladin.co.kr/product/35291/15/coversum/8965404029_1.jpg</cover>
# 				<categoryId>212364</categoryId>
# 				<categoryName>국내도서&gt;컴퓨터/모바일&gt;인공지능</categoryName>
# 				<publisher>프리렉</publisher>
# 				<salesPoint>8330</salesPoint>
#                 <adult>false</adult>
#
# 				<fixedPrice>true</fixedPrice>
#
# 				<customerReviewRank>10</customerReviewRank>
#
#                 <bestRank>6</bestRank>
#
#
#
# 			    <subInfo>
#
#
#
#
#
# 			    </subInfo>
#
#
#
#
# 			</item>
#
# 			<item itemId="354604730">
# 			    <title>챗GPT·퍼플렉시티·클로드·코파일럿·제미나이 다 잘함 - 퇴근이 빨라지는 58가지 AI 협업 실전 가이드</title>
# 				<link>http://www.aladin.co.kr/shop/wproduct.aspx?ItemId=354604730&amp;partner=openAPI&amp;start=api</link>
# 				<author>이호정 (지은이)</author>
# 				<pubDate>2025-01-15</pubDate>
# 				<description>시대적 환경에 맞춰 다섯 가지 주요 텍스트 생성형 AI인 챗지피티, 퍼플렉시티, 클로드, 코파일러, 제미나이의 특징과 활용법을 58개의 사례로 담아 자세히 안내한다. 즉, SNS에 올릴 홍보 게시글을 써야 하는 마케터라면 클로드를, 엑셀 작업이 많은 회계 담당자라면 코파일럿을, 다음 달에 해외 여행을 계획 중이라면 제미나이를 사용할 것을 추천하는 식이다.</description>
# 				<isbn>K902035349</isbn>
# 				<isbn13>9791194084099</isbn13>
# 				<priceSales>21600</priceSales>
# 				<priceStandard>24000</priceStandard>
# 				<mallType>BOOK</mallType>
# 				<stockStatus></stockStatus>
# 				<mileage>1200</mileage>
# 				<cover>https://image.aladin.co.kr/product/35460/47/coversum/k902035349_1.jpg</cover>
# 				<categoryId>212364</categoryId>
# 				<categoryName>국내도서&gt;컴퓨터/모바일&gt;인공지능</categoryName>
# 				<publisher>리코멘드</publisher>
# 				<salesPoint>2520</salesPoint>
#                 <adult>false</adult>
#
# 				<fixedPrice>true</fixedPrice>
#
# 				<customerReviewRank>10</customerReviewRank>
#
#                 <bestRank>7</bestRank>
#
#
#
# 			    <subInfo>
#
#
#
#
#
# 			    </subInfo>
#
#
#
#
# 			</item>
#
# 			<item itemId="355220835">
# 			    <title>스토리보드 그리고 AI - 애니메이션과 영상연출을 위한</title>
# 				<link>http://www.aladin.co.kr/shop/wproduct.aspx?ItemId=355220835&amp;partner=openAPI&amp;start=api</link>
# 				<author>김종율 (지은이)</author>
# 				<pubDate>2025-01-24</pubDate>
# 				<description>스토리보드의 기본 개념부터 실제 사용 사례를 중심으로 영상 기획자와 크리에이터들에게 실질적인 가이드를 제공한다. 프레임 비율과 구도를 분석하여 관객의 시선을 유도하는 방법을 설명하고, 볼륨 개념을 활용한 공간 연출 기법을 소개한다.</description>
# 				<isbn>K332036866</isbn>
# 				<isbn13>9791186573761</isbn13>
# 				<priceSales>23400</priceSales>
# 				<priceStandard>26000</priceStandard>
# 				<mallType>BOOK</mallType>
# 				<stockStatus></stockStatus>
# 				<mileage>1300</mileage>
# 				<cover>https://image.aladin.co.kr/product/35522/8/coversum/k332036866_1.jpg</cover>
# 				<categoryId>2632</categoryId>
# 				<categoryName>국내도서&gt;컴퓨터/모바일&gt;그래픽/멀티미디어&gt;그래픽 일반</categoryName>
# 				<publisher>비엘북스</publisher>
# 				<salesPoint>1960</salesPoint>
#                 <adult>false</adult>
#
# 				<fixedPrice>true</fixedPrice>
#
# 				<customerReviewRank>0</customerReviewRank>
#
#                 <bestRank>8</bestRank>
#
#
#
# 			    <subInfo>
#
#
#
#
#
# 			    </subInfo>
#
#
#
#
# 			</item>
#
# 			<item itemId="353285473">
# 			    <title>GPTs 제작·노출·고도화·수익화 진짜 잘함 - 챗GPT 활용의 끝판왕 GPTs AI 챗봇 만들기</title>
# 				<link>http://www.aladin.co.kr/shop/wproduct.aspx?ItemId=353285473&amp;partner=openAPI&amp;start=api</link>
# 				<author>이태경 (지은이)</author>
# 				<pubDate>2024-12-10</pubDate>
# 				<description>GPTs 제작 방법부터 시작해 완성된 GPTs를 사람들에게 노출시키고 고도화시켜 수익화하는 방법까지, GPTs를 진짜 잘하기 위한 방법을 체계적으로 설명한다.</description>
# 				<isbn>K302035477</isbn>
# 				<isbn13>9791194084068</isbn13>
# 				<priceSales>16920</priceSales>
# 				<priceStandard>18800</priceStandard>
# 				<mallType>BOOK</mallType>
# 				<stockStatus></stockStatus>
# 				<mileage>940</mileage>
# 				<cover>https://image.aladin.co.kr/product/35328/54/coversum/k302035477_1.jpg</cover>
# 				<categoryId>212364</categoryId>
# 				<categoryName>국내도서&gt;컴퓨터/모바일&gt;인공지능</categoryName>
# 				<publisher>리코멘드</publisher>
# 				<salesPoint>4655</salesPoint>
#                 <adult>false</adult>
#
# 				<fixedPrice>true</fixedPrice>
#
# 				<customerReviewRank>10</customerReviewRank>
#
#                 <bestRank>9</bestRank>
#
#
#
# 			    <subInfo>
#
#
#
#
#
# 			    </subInfo>
#
#
#
#
# 			</item>
#
# 			<item itemId="301543912">
# 			    <title>회사는 엑셀을 가르쳐주지 않아요</title>
# 				<link>http://www.aladin.co.kr/shop/wproduct.aspx?ItemId=301543912&amp;partner=openAPI&amp;start=api</link>
# 				<author>쏘피(박성희) (지은이)</author>
# 				<pubDate>2022-09-20</pubDate>
# 				<description>1:1 과외, 그룹 스터디, 대형 강의, 기업 출강, 탈잉 온·오프라인 클래스까지?총 10,000명 이상을 가르친 쏘피 튜터의 노하우가 고스란히 담긴 이 책은 엑셀 입문자의?눈높이에 맞춰 회사에서 반드시 필요한 엑셀 사용법을 설명한다.</description>
# 				<isbn>K212839588</isbn>
# 				<isbn13>9791129708328</isbn13>
# 				<priceSales>16200</priceSales>
# 				<priceStandard>18000</priceStandard>
# 				<mallType>BOOK</mallType>
# 				<stockStatus></stockStatus>
# 				<mileage>900</mileage>
# 				<cover>https://image.aladin.co.kr/product/30154/39/coversum/k212839588_1.jpg</cover>
# 				<categoryId>2602</categoryId>
# 				<categoryName>국내도서&gt;컴퓨터/모바일&gt;오피스(엑셀/파워포인트)&gt;엑셀</categoryName>
# 				<publisher>메가스터디북스</publisher>
# 				<salesPoint>21492</salesPoint>
#                 <adult>false</adult>
#
# 				<fixedPrice>true</fixedPrice>
#
# 				<customerReviewRank>10</customerReviewRank>
#
#                 <bestRank>10</bestRank><seriesInfo><seriesId>1058772</seriesId><seriesLink>http://www.aladin.co.kr/shop/common/wseriesitem.aspx?SRID=1058772&amp;partner=openAPI</seriesLink><seriesName>메가스터디 X 탈잉 러닝 시리즈 1</seriesName></seriesInfo>
#
#
#
# 			    <subInfo>
#
#
#
#
#
# 			    </subInfo>
#
#
#
#
# 			</item>
#
# </object>
# HTTP 응답 상태 코드: 200
# API 호출 오류: Expecting value: line 1 column 1 (char 0)
# Empty DataFrame
# Columns: []
# Index: []

# %%
def search_books(ttbkey, query="", queryType="ItemNewAll", start=1, max_results=50):
    url = "http://www.aladin.co.kr/ttb/api/ItemSearch.aspx"
    params = {
        "TTBKey": ttbkey,
        "Query": query,
        "QueryType": queryType,
        "SearchTarget": "Book",
        "CategoryId": "351",  # IT/컴퓨터 카테고리
        "start": start,
        "MaxResults": max_results,
        "Cover": "None",
        "output": "js",
        "Sort": "PublishTime",
        "Version": "20131101",
        "outofStockfilter": 1,
        "RecentPublishFilter": 1,
    }

    try:
        response = requests.get(url, params=params, timeout=10)
        # print(f"응답 데이터: {response.text}")
        # print(f"HTTP 응답 상태 코드: {response.status_code}")  # 상태 코드 확인
        # response.raise_for_status()  # HTTP 에러 발생 시 예외 처리
        data = response.json()  # JSON 데이터 파싱
    except (requests.RequestException, json.JSONDecodeError) as e:
        print(f"API 호출 오류: {e}")
        return pd.DataFrame()  # 빈 데이터프레임 반환

    if "item" in data:
        items = [
            {
                "title": item.get("title", ""),
                "link": item.get("link", ""),
                "author": item.get("author", ""),
                "pubDate": item.get("pubDate", ""),
                "description": item.get("description", ""),
                "isbn": item.get("isbn", ""),
                "isbn13": item.get("isbn13", ""),
                "itemId": item.get("itemId", ""),
                "priceSales": item.get("priceSales", ""),
                "priceStandard": item.get("priceStandard", ""),
                "categoryId": item.get("categoryId", ""),
                "categoryName": item.get("categoryName", ""),
                "publisher": item.get("publisher", ""),
                "customerReviewRank": item.get("customerReviewRank", ""),
            }
            for item in data["item"]
        ]
        return pd.DataFrame(items)
    else:
        print("API 호출 성공, 그러나 반환된 데이터가 없습니다.")
        return pd.DataFrame()  # 빈 데이터프레임 반환

def collect_books_no_limit(ttbkey, query=""):
    df = pd.DataFrame(columns=[
        "title", "link", "author", "pubDate", "description", "isbn", "isbn13",
        "itemId", "priceSales", "priceStandard", "categoryId", "categoryName",
        "publisher", "customerReviewRank",
    ])

    start = 1
    max_results_per_call = 50

    while True:  # start <= 5 : 변경된 부분: 5회 반복으로 제한
        new_data = search_books(ttbkey, query, start=start, max_results=max_results_per_call)

        if new_data.empty:
            print("데이터 수집이 중단되었습니다. (API 호출 실패 또는 데이터 부족)")
            break

        df = pd.concat([df, new_data]).drop_duplicates(subset=["itemId"], ignore_index=True)
        print(start)
        start += 1

        if len(new_data) < max_results_per_call:
            print("더 이상 데이터를 수집할 수 없습니다.")
            break

    return df

# %%
collect_books_no_limit(TTBKEY, "python")
# Out:
# 1
# 더 이상 데이터를 수집할 수 없습니다.
#                                                title  \
# 0     밑바닥부터 시작하는 딥러닝 1 - 파이썬으로 익히는 딥러닝 이론과 구현, 리마스터판
# 1                                 핵심만 쏙쏙! 쉽게 배우는 파이썬
# 2       AI 시대의 파이썬 데이터 분석 - 다양한 예제로 실습하고 프로젝트로 완성한다!
# 3                           파이썬 마스터 - 실생활 융합 예제로 배우는
# 4                                            파이썬 워크북
# 5                            최신 파이썬 완전정복 : 기초에서 심화까지
# 6  파이썬 업무 자동화 일잘러 되기 + 챗GPT - 파이썬, 엑셀, 워드, 파워포인트,...
# 7                            파이썬으로 제어하는 마이크로비트 - 개정판
# 8                    마이크로파이썬을 활용한 사물인터넷 - 챗GPT로 코딩하기
# 9                                        Python 리터러시
#
#                                                 link  \
# 0  http://www.aladin.co.kr/shop/wproduct.aspx?Ite...
# 1  http://www.aladin.co.kr/shop/wproduct.aspx?Ite...
# 2  http://www.aladin.co.kr/shop/wproduct.aspx?Ite...
# 3  http://www.aladin.co.kr/shop/wproduct.aspx?Ite...
# 4  http://www.aladin.co.kr/shop/wproduct.aspx?Ite...
# 5  http://www.aladin.co.kr/shop/wproduct.aspx?Ite...
# 6  http://www.aladin.co.kr/shop/wproduct.aspx?Ite...
# 7  http://www.aladin.co.kr/shop/wproduct.aspx?Ite...
# 8  http://www.aladin.co.kr/shop/wproduct.aspx?Ite...
# 9  http://www.aladin.co.kr/shop/wproduct.aspx?Ite...
#
#                           author     pubDate  \
# 0  사이토 고키 (지은이), 개앞맵시(이복연) (옮긴이)  2025-01-24
# 1            양숙희, 장은실, 오경선 (지은이)  2025-01-24
# 2                      오세종 (지은이)  2025-01-19
# 3                 김종훈, 김동건 (지은이)  2025-01-17
# 4                      안기수 (지은이)  2025-01-17
# 5                      강환수 (지은이)  2025-01-12
# 6                      메이허 (지은이)  2025-01-10
# 7                      북마크 (지은이)  2025-01-02
# 8                      양재삼 (지은이)  2025-01-02
# 9                      민상준 (지은이)  2024-12-30
#
#                                          description        isbn  \
# 0  딥러닝의 핵심 개념을 ‘밑바닥부터’ 구현해보며 기초를 한 걸음씩 탄탄하게 다질 수 ...  K222036504
# 1  파이썬의 기초를 다지는 데 꼭 필요한 내용을 선별하여 복잡함을 최소화했다. “왜 파...  8989383129
# 2  파이썬을 활용하여 데이터 분석을 배우려는 독자를 대상으로 하며, 다양한 실습을 통해...  K182036395
# 3  파이썬 프로그래밍 기초와 데이터 분석을 한 권으로 마스터하는 파이썬 기본서. 파이썬...  K522036896
# 4  파이썬 언어를 쉽게 이해하기 위해 워크북으로 실습하는 프로그래밍 입문서다. 코딩을 ...  K712036278
# 5                                                     K992035710
# 6  반복 작업과 대량의 데이터 처리 작업에 지쳐버린 당신에게 이 책을 선물한다. 파일,...  K802035420
# 7                                                     K412036098
# 8  간결한 언어인 마이크로파이썬을 활용해 누구나 쉽게 사물인터넷(IoT)을 시작할 수 ...  K932036178
# 9                                                     K852036099
#
#           isbn13     itemId priceSales priceStandard categoryId  \
# 0  9791169213387  356399264      23400         26000       6794
# 1  9788989383123  356277845      24000         24000       6734
# 2  9791173400087  356316564      32000         32000     179288
# 3  9791173400018  355902182      32000         32000       6734
# 4  9791192932682  355394344      15000         15000       6734
# 5  9791156002352  353808974      34000         34000       6734
# 6  9791194383130  354137053      32400         36000       6357
# 7  9791141971335  356006960      10900         10900       6734
# 8  9791173400049  355341238      28000         28000       6734
# 9  9791141970338  356015432      19200         19200       6734
#
#                         categoryName    publisher customerReviewRank
# 0      국내도서>컴퓨터/모바일>컴퓨터 공학>데이터베이스 개론        한빛미디어                  9
# 1          국내도서>컴퓨터/모바일>프로그래밍 언어>파이썬          배움터                  0
# 2            국내도서>수험서/자격증>민간자격>데이터분석   한빛아카데미(교재)                  0
# 3          국내도서>컴퓨터/모바일>프로그래밍 언어>파이썬   한빛아카데미(교재)                  0
# 4          국내도서>컴퓨터/모바일>프로그래밍 언어>파이썬           생능                  0
# 5          국내도서>컴퓨터/모바일>프로그래밍 언어>파이썬  홍릉(홍릉과학출판사)                  0
# 6  국내도서>컴퓨터/모바일>프로그래밍 언어>프로그래밍 언어 기타      골든래빗(주)                  0
# 7          국내도서>컴퓨터/모바일>프로그래밍 언어>파이썬   부크크(bookk)                  0
# 8          국내도서>컴퓨터/모바일>프로그래밍 언어>파이썬   한빛아카데미(교재)                  0
# 9          국내도서>컴퓨터/모바일>프로그래밍 언어>파이썬   부크크(bookk)                  0
